# %%
import numpy as np
import pandas as pd

# %%
veriler =pd.read_csv("veriler.csv")
veriler
# Out:
#    ulke  boy  kilo  yas cinsiyet
# 0    tr  130    30   10        e
# 1    tr  125    36   11        e
# 2    tr  135    34   10        k
# 3    tr  133    30    9        k
# 4    tr  129    38   12        e
# 5    tr  180    90   30        e
# 6    tr  190    80   25        e
# 7    tr  175    90   35        e
# 8    tr  177    60   22        k
# 9    us  185   105   33        e
# 10   us  165    55   27        k
# 11   us  155    50   44        k
# 12   us  160    58   39        k
# 13   us  162    59   41        k
# 14   us  167    62   55        k
# 15   fr  174    70   47        e
# 16   fr  193    90   23        e
# 17   fr  187    80   27        e
# 18   fr  183    88   28        e
# 19   fr  159    40   29        k
# 20   fr  164    66   32        k
# 21   fr  166    56   42        k

# %%
from sklearn import preprocessing
labelEnc=preprocessing.LabelEncoder()
oneHotEnc=preprocessing.OneHotEncoder()

ulke=veriler.iloc[:,0:1].values
ulke[:,0]=labelEnc.fit_transform(veriler.iloc[:,0])
ulke=oneHotEnc.fit_transform(ulke).toarray()

cinsiyet=veriler.iloc[:,-1:].values
cinsiyet[:,-1]=labelEnc.fit_transform(veriler.iloc[:,-1])

# %%
sonuc=pd.DataFrame(data=ulke,index=range(22),columns=["fr","tr","us"])
sonuc2=pd.DataFrame(data=veriler,index=range(22),columns=["boy","kilo","yas"])
s=pd.concat([sonuc,sonuc2],axis=1)
sonuc3=pd.DataFrame(data=cinsiyet,index=range(22),columns=["cinsiyet"])

yeniVeri=pd.concat([s,sonuc3],axis=1)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(s,sonuc3,test_size=0.33,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
y_yas=yeniVeri.iloc[:,5:6]
x_yas=pd.concat([yeniVeri.iloc[:,0:5],yeniVeri.iloc[:,6:]],axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_yas,y_yas,test_size=0.33,random_state=0)

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
yas_tahmin=regressor.predict(x_test)

# %%
x_boy=pd.concat([yeniVeri.iloc[:,0:3],yeniVeri.iloc[:,4:]],axis=1)
y_boy=yeniVeri.iloc[:,3:4]

# %%
x_train,x_test,y_train,y_test=train_test_split(x_boy,y_boy,test_size=0.33,random_state=0)

# %%
regressor.fit(x_train,y_train)
boy_tahmin=regressor.predict(x_test)

# %%
y_test
# Out:
#     boy
# 20  164
# 10  165
# 14  167
# 13  162
# 1   125
# 21  166
# 11  155
# 19  159

# %%
boy_tahmin
# Out:
# array([[182.26638686],
#        [152.87161474],
#        [162.79386375],
#        [158.30668577],
#        [130.82888952],
#        [173.96138408],
#        [150.12782663],
#        [157.26898922]])
